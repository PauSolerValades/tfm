# %%
import polars as pl

# %%
df = pl.read_parquet("../data/top_level-00000-of-00001.parquet")
df.head()
# Out:
# shape: (5, 13)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ did       ┆ post_uri  ┆ post_text ┆ created_a ┆ … ┆ follows_a ┆ profile_a ┆ reply_con ┆ validati │
# │ ---       ┆ ---       ┆ ---       ┆ t_iso     ┆   ┆ t_moment  ┆ t_moment  ┆ text      ┆ on_check │
# │ str       ┆ str       ┆ str       ┆ ---       ┆   ┆ ---       ┆ ---       ┆ ---       ┆ s        │
# │           ┆           ┆           ┆ str       ┆   ┆ list[null ┆ str       ┆ str       ┆ ---      │
# │           ┆           ┆           ┆           ┆   ┆ ]         ┆           ┆           ┆ struct[4 │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ ]        │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ did:plc:g ┆ at://did: ┆ Putin     ┆ 2025-12-0 ┆ … ┆ []        ┆ {"did":   ┆           ┆ {true,tr │
# ...
